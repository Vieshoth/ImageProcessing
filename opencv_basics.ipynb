# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import cv2

# %%
img = cv2.imread('/home/zebra/vieshoth/study/ip/notebook/Computer-Vision-with-Python/DATA/00-puppy.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1300, 1950, 3)

# %%
#Matplot lib -> R G B
#Opencv -> B G R

# %%
plt.imshow(img)

# %%
rgbimage = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(rgbimage)

# %%
imggray = cv2.imread('/home/zebra/vieshoth/study/ip/notebook/Computer-Vision-with-Python/DATA/00-puppy.jpg', cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(imggray)

# %%
plt.imshow(imggray, cmap='gray')

# %%
plt.imshow(rgbimage)

# %%
rgbimage.shape
# Out:
# (1300, 1950, 3)

# %%
new_image = cv2.resize(rgbimage, (1000, 400))

# %%
plt.imshow(new_image)

# %%
new_image.shape
# Out:
# (400, 1000, 3)

# %%
new_image = cv2.resize(rgbimage, (0,0), rgbimage, 0.5,0.5)

# %%
plt.imshow(new_image)

# %%
new_image.shape
# Out:
# (650, 975, 3)

# %%
cv2.imwrite('smallpuppy.jpg', new_image)
# Out:
# True
